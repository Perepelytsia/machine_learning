# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import numpy as np
plt.style.use('ggplot')
data = pd.read_json('./data.json')

# %%
X = data.x.values.reshape(-1,1)
y = data.y.values.reshape(-1,1)

# %%
def example(regressor, X, y):
    regressor.fit(X, y)
    y_pred = regressor.predict(X)
    plt.figure(figsize=(7, 5), dpi=80)
    
    if isinstance(reg.coef_[0], np.ndarray): 
        coef = reg.coef_[0][0]
    else:
        coef = reg.coef_[0]
        
    if isinstance(reg.intercept_, np.ndarray): 
        intercept = reg.intercept_[0]
    else:
        intercept = reg.intercept_
    
    title = 'coef= ' + str(round(coef, 4)) + '     intercept= ' + str(round(intercept, 2))
    plt.scatter(X, y_pred, color='red', label=title)
    plt.scatter(X, y,  color='black')
    plt.legend(fontsize=12)
    plt.show()

# %% [markdown]
# # Ordinary Least Squares

# %%
reg = linear_model.LinearRegression()
example(reg, X, y)

# %% [markdown]
# # Ridge regression

# %%
reg = linear_model.Ridge(alpha=.5)
example(reg, X, y)

# %% [markdown]
# # Lasso

# %%
reg = linear_model.LassoLars(alpha=.1)
example(reg, X, y)

# %% [markdown]
# # Elastic-Net

# %%
reg = linear_model.ElasticNet(alpha=0.1, l1_ratio=0.7)
example(reg, X, y)

# %% [markdown]
# # LARS Lasso

# %%
reg = linear_model.LassoLars(alpha=.1)
example(reg, X, y)

# %% [markdown]
# # Bayesian Ridge Regression

# %%
reg = linear_model.BayesianRidge()
example(reg, X, y)
# Out:
# /home/alex/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %% [markdown]
# # Stochastic Gradient Descent

# %%
reg = linear_model.SGDRegressor(max_iter=1000, tol=1e-3)
example(reg, X, y)
# Out:
# /home/alex/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)

# %% [markdown]
# # Passive Aggressive Algorithms

# %%
reg = linear_model.PassiveAggressiveRegressor(max_iter=100, random_state=0, tol=1e-3)
example(reg, X, y)
# Out:
# /home/alex/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
